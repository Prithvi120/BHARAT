# %% [markdown]
# IMPORTING DEPENDENCIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset=pd.read_csv('/content/IRIS.csv')

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# FULL DATASET

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# CHECKING FOR MISSING VALUES

# %%
dataset.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
dataset.shape
# Out:
# (150, 5)

# %% [markdown]
# TARGET FEATURE

# %%
dataset['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# LABEL ENCODING

# %%
label=LabelEncoder()
dataset['species']=label.fit_transform(dataset['species'])
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# SPLITTING THE FEATURES

# %%
x=dataset.drop(columns='species',axis=1)
y=dataset['species']
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %% [markdown]
# TRAIN AND TEST DATA

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify =y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (150, 4) (120, 4) (30, 4)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 0.33661809, -0.32913365,  0.54679015,  0.26968039],
#        [ 0.58367723, -0.79379292,  0.66150138,  0.79375563],
#        [ 0.58367723,  0.60018489,  1.29241309,  1.71088731],
#        [ 0.08955894, -0.09680401,  0.7762126 ,  0.79375563],
#        [-1.14573679,  0.13552562, -1.28858938, -1.43356416],
#        [ 0.08955894, -0.09680401,  0.2600121 ,  0.4006992 ],
#        [-0.28102978, -0.09680401,  0.43207893,  0.4006992 ],
#        [ 1.07779553, -1.25845219,  1.17770187,  0.79375563],
#        [ 0.21308851, -0.32913365,  0.43207893,  0.4006992 ],
#        [-0.40455935, -1.25845219,  0.14530088,  0.13866158],
#        [ 0.58367723, -1.25845219,  0.71885699,  0.92477444],
#        [ 0.21308851, -1.9554411 ,  0.14530088, -0.25439486],
#        [ 0.58367723, -1.72311147,  0.37472332,  0.13866158],
#        [-0.40455935, -1.72311147,  0.14530088,  0.13866158],
#        [ 0.70720681, -0.56146329,  1.06299065,  1.31783088],
#        [-0.40455935, -1.49078183, -0.02676595, -0.25439486],
#        [ 0.58367723, -0.32913365,  1.06299065,  0.79375563],
#        [ 1.2013251 ,  0.36785526,  1.23505748,  1.44884969],
#        [-1.26926637,  0.83251453, -1.05916694, -1.30254535],
#        [ 2.31309126, -0.09680401,  1.3497687 ,  1.44884969],
#        [ 0.83073638, -0.09680401,  1.00563504,  0.79375563],
#        [ 0.33661809, -1.02612256,  1.06299065,  0.26968039],
#        [ 0.46014766, -0.32913365,  0.31736771,  0.13866158],
#        [-1.26926637, -0.09680401, -1.34594499, -1.43356416],
#        [ 1.2013251 , -0.09680401,  1.00563504,  1.18681207],
#        [ 0.70720681, -0.56146329,  1.06299065,  1.18681207],
#        [-0.03397063, -0.79379292,  0.7762126 ,  0.92477444]])

# %%
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[-1.25362483, -0.2372781 , -1.32483532, -1.22270536],
#        [ 1.12524157,  0.22196983,  1.04225272,  1.44501543],
#        [ 0.3322861 , -0.69652603,  0.54681569,  0.77808523],
#        [-1.70674224, -0.46690207, -1.32483532, -1.3560914 ],
#        [ 0.78540351, -0.46690207,  0.43671857,  0.11115503],
#        [ 2.03147639, -0.69652603,  1.59273831,  1.04485731],
#        [ 0.44556545,  0.68121777,  0.98720416,  1.57840147],
#        [-0.23411066, -1.38539793,  0.6569128 ,  1.04485731],
#        [-0.23411066,  1.59971364, -1.15968964, -1.22270536],
#        [-1.48018354,  1.1404657 , -1.54502955, -1.3560914 ],
#        [-0.23411066, -0.69652603,  0.16147577,  0.11115503],
#        [-0.12083131, -0.92615   ,  0.05137866, -0.02223101],
#        [-0.80050742, -0.92615   ,  0.05137866,  0.24454107],
#        [ 0.55884481, -0.00765413,  0.9321556 ,  0.77808523],
#        [-1.02706613,  0.68121777, -1.26978676, -1.3560914 ],
#        [ 2.03147639,  1.59971364,  1.59273831,  1.31162939],
#        [-0.23411066, -0.2372781 ,  0.21652433, -0.02223101],
#        [-1.02706613,  0.4515938 , -1.32483532, -1.3560914 ],
#        [ 0.55884481,  0.22196983,  0.82205848,  1.44501543],
#        [-1.25362483,  0.68121777, -1.2147382 , -1.3560914 ],
#        [ 1.01196222, -0.69652603,  0.54681569,  0.24454107],
#        [ 0.44556545, -1.38539793,  0.60186424,  0.37792711],
#        [-1.02706613,  0.91084174, -1.2147382 , -0.82254724],
#        [-0.12083131, -0.92615   ,  0.16147577, -0.28900309],
#        [ 0.21900675, -0.2372781 ,  0.43671857,  0.24454107],
#        [ 1.12524157, -0.00765413,  0.87710704,  1.17824335],
#        [ 1.69163833, -0.69652603,  1.26244695,  0.91147127],
#        [-1.02706613,  0.91084174, -1.37988388, -1.22270536],
#        [-0.34739001, -1.38539793,  0.05137866, -0.15561705],
#        [-0.23411066,  2.97745744, -1.26978676, -1.08931932]])

# %% [markdown]
# LOGISTIC REGRESSION

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred1=model.predict(x_test)
accuracy_score(y_test,pred1)
# Out:
# 1.0

# %% [markdown]
# SVM

# %%
from sklearn import svm
svm=svm.SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred2=svm.predict(x_test)
accuracy_score(pred2,y_test)
# Out:
# 1.0

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RF=model1.predict(x_test)
accuracy_score(RF,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred4=GBC.predict(x_test)
accuracy_score(y_test,pred4)
# Out:
# 1.0
